# %% [markdown]
# #Project: Mining Mental Health Patterns in User Tweets and Resource Allocation via Sentiment Analysis, Topic Modeling and Transfer Learning

# %% [markdown]
# **IST 736 : Text Mining under Prof. Bei Yu**

# %% [markdown]
#  **Collaborators: Aditi Pala, Yashaswini Kulkarni, Viha Mashruwala**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report, confusion_matrix
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.cm as cm
from matplotlib import rcParams
from collections import Counter
from nltk.tokenize import RegexpTokenizer
import re
import string
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Sentiment data

# %%
train160 = pd.read_csv('/content/drive/My Drive/Text Mining Project/training.1600000.processed.noemoticon.csv', encoding = "ISO-8859-1", engine="python")

# %%
train160.head()
# Out:
#    Unnamed: 0             post_id                    post_created  \
# 0           0  637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1           1  637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 2           2  637749345908051968  Sat Aug 29 22:11:07 +0000 2015
# 3           3  637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4           4  637696327485366272  Sat Aug 29 18:40:26 +0000 2015
#
#                                            post_text     user_id  followers  \
# 0  its just over years since i was diagnosed with...  1013187241         84
# 1  its sunday i need a break so im planning to sp...  1013187241         84
# 2  awake but tired i need to sleep but my brain h...  1013187241         84
# 3  rt retro bears make perfect gifts and are grea...  1013187241         84
# 4  its hard to say whether packing lists are maki...  1013187241         84
#
#    friends  favourites  statuses  retweets  label
# 0      211         251       837         0      1
# 1      211         251       837         1      1
# 2      211         251       837         0      1
# 3      211         251       837         2      1
# 4      211         251       837         1      1

# %%
train160.shape
# Out:
# (20000, 11)

# %% [markdown]
# Checking for data imbalance:

# %%
query_counts = train160['label'].value_counts()
print(query_counts)
# Out:
# 1    10000
# 0    10000
# Name: label, dtype: int64

# %% [markdown]
# Conclusion : Data is balanced for both positive and negative labels

# %%
train160 = train160[['post_text','label']]

# %%
train160.columns=['text','label']

# %%
train160.head()
# Out:
#                                                 text  label
# 0  its just over years since i was diagnosed with...      1
# 1  its sunday i need a break so im planning to sp...      1
# 2  awake but tired i need to sleep but my brain h...      1
# 3  rt retro bears make perfect gifts and are grea...      1
# 4  its hard to say whether packing lists are maki...      1

# %% [markdown]
# Assigning 1 to positive sentiment 4 for consistency

# %%
train160['label'][train160['label']==4]=1

#Seperating positive and negative tweets
train160_pos = train160[train160['label'] == 1]
train160_neg = train160[train160['label'] == 0]

# %% [markdown]
# # Data Preprocessing - Senti140 Dataset

# %%
#Making statement text in lower case
train160['text']= train160['text'].str.lower()

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

# Get the list of English stopwords
stopwords_list = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
#Cleaning and removing the above stop words list from the tweet text
STOPWORDS = set(stopwords.words('english'))
def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])
train160['text'] = train160['text'].apply(lambda text: cleaning_stopwords(text))
train160['text'].head()
# Out:
# 0    years since diagnosed anxiety depression today...
# 1    sunday need break im planning spend little tim...
# 2                   awake tired need sleep brain ideas
# 3    rt retro bears make perfect gifts great beginn...
# 4    hard say whether packing lists making life eas...
# Name: text, dtype: object

# %%
#Cleaning and removing punctuations
english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)

train160['text']= train160['text'].apply(lambda x: cleaning_punctuations(x))
train160['text'].head()
# Out:
# 0    years since diagnosed anxiety depression today...
# 1    sunday need break im planning spend little tim...
# 2                   awake tired need sleep brain ideas
# 3    rt retro bears make perfect gifts great beginn...
# 4    hard say whether packing lists making life eas...
# Name: text, dtype: object

# %%
#Cleaning and removing repeating characters
def cleaning_repeating_char(text):
    return re.sub(r'(.)\1+', r'\1', text)

train160['text'] = train160['text'].apply(lambda x: cleaning_repeating_char(x))
train160['text'].head()
# Out:
# 0    years since diagnosed anxiety depresion today ...
# 1    sunday ned break im planing spend litle time p...
# 2                     awake tired ned slep brain ideas
# 3    rt retro bears make perfect gifts great begine...
# 4    hard say whether packing lists making life eas...
# Name: text, dtype: object

# %%
#Cleaning and removing email
def cleaning_email(train160):
    return re.sub('@[^\s]+', ' ', train160)

train160['text']= train160['text'].apply(lambda x: cleaning_email(x))
train160['text'].tail()
# Out:
# 19995                      day without sunshine like night
# 19996    borens laws charge ponder trouble delegate dou...
# 19997    flow chart thoroughly oversold piece program d...
# 19998                   ships safe harbor never meant stay
# 19999                        black holes god dividing zero
# Name: text, dtype: object

# %%
#Cleaning and removing URL's
def cleaning_URLs(train160):
    return re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',train160)

train160['text'] = train160['text'].apply(lambda x: cleaning_URLs(x))
train160['text'].tail()
# Out:
# 19995                      day without sunshine like night
# 19996    borens laws charge ponder trouble delegate dou...
# 19997    flow chart thoroughly oversold piece program d...
# 19998                   ships safe harbor never meant stay
# 19999                        black holes god dividing zero
# Name: text, dtype: object

# %%
#Cleaning and removing Numeric numbers
def cleaning_numbers(train160):
    return re.sub('[0-9]+', '', train160)
train160['text'] = train160['text'].apply(lambda x: cleaning_numbers(x))
train160['text'].tail()
# Out:
# 19995                      day without sunshine like night
# 19996    borens laws charge ponder trouble delegate dou...
# 19997    flow chart thoroughly oversold piece program d...
# 19998                   ships safe harbor never meant stay
# 19999                        black holes god dividing zero
# Name: text, dtype: object

# %%
#Getting tokenization of tweet text
tokenizer = RegexpTokenizer(r'\w+')
train160['tokens'] = train160['text'].apply(tokenizer.tokenize)
train160['tokens'].head()
# Out:
# 0    [years, since, diagnosed, anxiety, depresion, ...
# 1    [sunday, ned, break, im, planing, spend, litle...
# 2              [awake, tired, ned, slep, brain, ideas]
# 3    [rt, retro, bears, make, perfect, gifts, great...
# 4    [hard, say, whether, packing, lists, making, l...
# Name: tokens, dtype: object

# %%
#Applying Lemmatizer
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')


lm = nltk.WordNetLemmatizer()
def lemmatizer_on_text(train160):
    text = [lm.lemmatize(word) for word in train160]
    return train160

train160['tokens'] = train160['tokens'].apply(lambda x: lemmatizer_on_text(x))
train160['tokens'].head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# 0    [years, since, diagnosed, anxiety, depresion, ...
# 1    [sunday, ned, break, im, planing, spend, litle...
# 2              [awake, tired, ned, slep, brain, ideas]
# 3    [rt, retro, bears, make, perfect, gifts, great...
# 4    [hard, say, whether, packing, lists, making, l...
# Name: tokens, dtype: object

# %%
train160.head()
# Out:
#                                                 text  label  \
# 0  years since diagnosed anxiety depresion today ...      1
# 1  sunday ned break im planing spend litle time p...      1
# 2                   awake tired ned slep brain ideas      1
# 3  rt retro bears make perfect gifts great begine...      1
# 4  hard say whether packing lists making life eas...      1
#
#                                               tokens
# 0  [years, since, diagnosed, anxiety, depresion, ...
# 1  [sunday, ned, break, im, planing, spend, litle...
# 2            [awake, tired, ned, slep, brain, ideas]
# 3  [rt, retro, bears, make, perfect, gifts, great...
# 4  [hard, say, whether, packing, lists, making, l...

# %% [markdown]
# # Import Mental Health Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Text Mining Project/Mental-Health-Twitter.csv', encoding = "ISO-8859-1", engine="python")

# %%
df.head()
# Out:
#    Unnamed: 0             post_id                    post_created  \
# 0           0  637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1           1  637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 2           2  637749345908051968  Sat Aug 29 22:11:07 +0000 2015
# 3           3  637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4           4  637696327485366272  Sat Aug 29 18:40:26 +0000 2015
#
#                                            post_text     user_id  followers  \
# 0  It's just over 2 years since I was diagnosed w...  1013187241         84
# 1  It's Sunday, I need a break, so I'm planning t...  1013187241         84
# 2  Awake but tired. I need to sleep but my brain ...  1013187241         84
# 3  RT @SewHQ: #Retro bears make perfect gifts and...  1013187241         84
# 4  Itâs hard to say whether packing lists are m...  1013187241         84
#
#    friends  favourites  statuses  retweets  label
# 0      211         251       837         0      1
# 1      211         251       837         1      1
# 2      211         251       837         0      1
# 3      211         251       837         2      1
# 4      211         251       837         1      1

# %%
df.isnull().sum() # check for missing values
# Out:
# Unnamed: 0      0
# post_id         0
# post_created    0
# post_text       0
# user_id         0
# followers       0
# friends         0
# favourites      0
# statuses        0
# retweets        0
# label           0
# dtype: int64

# %% [markdown]
# Checking for data imbalance:

# %%
query_counts_df = df['label'].value_counts()
print(query_counts_df)
# Out:
# 1    10000
# 0    10000
# Name: label, dtype: int64

# %% [markdown]
# Conclusion : Data is balanced for both positive and negative labels

# %% [markdown]
# Let's focus on the tweets by top 5 users - we do this to find mental health posts that are have high frequency of tweets

# %%
import pandas as pd

user_tweet_counts = df.groupby('user_id').size().reset_index(name='tweet_count')

# Get the top 5 users based on tweet count
top_users = user_tweet_counts.nlargest(5, 'tweet_count')

# Combine tweets of top 5 users
top_user_data = pd.concat([df[df['user_id'] == user_id][['user_id', 'post_text']] for user_id in top_users['user_id']], ignore_index=True)

# Display the subset of data for the user
display(top_user_data.head())
# Out:
#      user_id                                          post_text
# 0  490044008  Mom: "So I was checking your credit card state...
# 1  490044008  (Pretends I didnt spend 2k a day buying Hearth...
# 2  490044008                              No money no talk meh.
# 3  490044008                  Well now. https://t.co/0r7vfr1sv4
# 4  490044008  RT @HDDoesGaming: PASS INTO THE IRIS https://t...

# %%
# Display the subset of data for the user
display(top_user_data)
# Out:
#          user_id                                          post_text
# 0      490044008  Mom: "So I was checking your credit card state...
# 1      490044008  (Pretends I didnt spend 2k a day buying Hearth...
# 2      490044008                              No money no talk meh.
# 3      490044008                  Well now. https://t.co/0r7vfr1sv4
# 4      490044008  RT @HDDoesGaming: PASS INTO THE IRIS https://t...
# ...          ...                                                ...
# 7373  1616997456  Overcome Depressive disorders: ADHD plus drugs...
# 7374  1616997456  Overcome Depression: A scheduled appointment w...
# 7375  1616997456  Overcome Depression: A scheduled appointment w...
# 7376  1616997456  Overcome Depression: ARIEL SHARON (1928-2014) ...
# 7377  1616997456  Overcome Depression: Ocean swell sets off surf...
#
# [7378 rows x 2 columns]

# %% [markdown]
# There are about 7378 tweets included in top 5 user data

# %% [markdown]
# # Data Preprocessing - top 5 users from mental health dataset

# %%
import re
import string

# Function to remove links from text
def remove_links(text):
    return re.sub(r'http\S+', '', text)

# Function to remove user names from text
def remove_usernames(text):
    return re.sub(r'@\w+', '', text)

# Function to remove punctuation from text
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# Function to remove special characters
def remove_special_characters(text):
    return re.sub(r'[^a-zA-Z\s]', '', text)

# Apply the functions to your 'post_text' column
top_user_data["post_text"] = top_user_data["post_text"].apply(remove_links)
top_user_data["post_text"] = top_user_data["post_text"].apply(remove_usernames)
top_user_data["post_text"] = top_user_data["post_text"].apply(remove_punctuation)
top_user_data["post_text"] = top_user_data["post_text"].apply(remove_special_characters)

# Change all characters in tweets to lower case
top_user_data["post_text"] = top_user_data["post_text"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# Extract 'post_text' as docs
docs = top_user_data['post_text']

# %%
# Apply the functions to your 'post_text' column
df["post_text"] = df["post_text"].apply(remove_links)
df["post_text"] = df["post_text"].apply(remove_usernames)
df["post_text"] = df["post_text"].apply(remove_punctuation)
df["post_text"] = df["post_text"].apply(remove_special_characters)

# Change all characters in tweets to lower case
df["post_text"] = df["post_text"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df.shape
# Out:
# (20000, 11)

# %%
top_user_data.head()
# Out:
#      user_id                                          post_text
# 0  490044008  mom so i was checking your credit card stateme...
# 1  490044008  pretends i didnt spend k a day buying hearthst...
# 2  490044008                               no money no talk meh
# 3  490044008                                           well now
# 4  490044008                              rt pass into the iris

# %%
top_user_data
# Out:
#          user_id                                          post_text
# 0      490044008  mom so i was checking your credit card stateme...
# 1      490044008  pretends i didnt spend k a day buying hearthst...
# 2      490044008                               no money no talk meh
# 3      490044008                                           well now
# 4      490044008                              rt pass into the iris
# ...          ...                                                ...
# 7373  1616997456  overcome depressive disorders adhd plus drugs ...
# 7374  1616997456  overcome depression a scheduled appointment wi...
# 7375  1616997456  overcome depression a scheduled appointment wi...
# 7376  1616997456          overcome depression ariel sharon isracast
# 7377  1616997456  overcome depression ocean swell sets off surf ...
#
# [7378 rows x 2 columns]

# %%
print(top_user_data.columns)
print(df.columns)
# Out:
# Index(['user_id', 'post_text'], dtype='object')
# Index(['Unnamed: 0', 'post_id', 'post_created', 'post_text', 'user_id',
#        'followers', 'friends', 'favourites', 'statuses', 'retweets', 'label'],
#       dtype='object')

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# using BERTopic

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 30.7 MB/s eta 0:00:00
#   Installing build dependencies ... canceled
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/structs.py", line 156, in __bool__
#     return bool(self._sequence)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 293, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/distributions/sdist.py", line 38, in prepare_distribution_metadata
#     self._prepare_build_backend(finder)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/distributions/sdist.py", line 70, in _prepare_build_backend
#     self.req.build_env.install_requirements(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/build_env.py", line 217, in install_requirements
#     self._install_requirements(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/build_env.py", line 275, in _install_requirements
#     call_subprocess(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/subprocess.py", line 166, in call_subprocess
#     line: str = proc.stdout.readline()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 207, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1465, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1624, in _log
#     self.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 968, in handle
#     self.emit(record)
#   File "/usr/lib/python3.10/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1218, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 686, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/usr/lib/python3.10/logging/__init__.py", line 636, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.10/traceback.py", line 119, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#   File "/usr/lib/python3.10/traceback.py", line 502, in __init__
#     self.stack = StackSummary.extract(
#   File "/usr/lib/python3.10/traceback.py", line 383, in extract
#     f.line
#   File "/usr/lib/python3.10/traceback.py", line 306, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#   File "/usr/lib/python3.10/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/usr/lib/python3.10/tokenize.py", line 396, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/usr/lib/python3.10/tokenize.py", line 365, in detect_encoding
#     first = read_or_stop()
#   File "/usr/lib/python3.10/tokenize.py", line 323, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ^C

# %%
# !pip show joblib
# Out:
# Name: joblib
# Version: 1.3.2
# Summary: Lightweight pipelining with Python functions
# Home-page:
# Author:
# Author-email: Gael Varoquaux <gael.varoquaux@normalesup.org>
# License: BSD 3-Clause
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: hdbscan, imbalanced-learn, librosa, mlxtend, music21, nltk, pynndescent, scikit-learn

# %% [markdown]
# ###**BERTopic**
#
# Training model on Mental Health top 5 user data to research mental health related keywords

# %%
from bertopic import BERTopic

topic_model = BERTopic(embedding_model="all-MiniLM-L12-v2", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2023-12-12 22:18:39,332 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/231 [00:00<?, ?it/s]
# 2023-12-12 22:21:07,605 - BERTopic - Embedding - Completed ✓
# 2023-12-12 22:21:07,608 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-12 22:21:57,598 - BERTopic - Dimensionality - Completed ✓
# 2023-12-12 22:21:57,605 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-12 22:22:13,453 - BERTopic - Cluster - Completed ✓
# 2023-12-12 22:22:13,482 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-12 22:22:14,562 - BERTopic - Representation - Completed ✓

# %%
freq = topic_model.get_topic_info();
num_topics = len(freq) -1
print(num_topics)
freq.head(num_topics)
# Out:
# 120
#      Topic  Count                                               Name  \
# 0       -1   2624                                   -1_the_to_and_it
# 1        0    604                0_user_account_gander_tabletsrental
# 2        1    330                    1_following_twitter_hello_thank
# 3        2    230                          2_rt_this_crying_password
# 4        3    223         3_depression_treatments_overcome_treatment
# ..     ...    ...                                                ...
# 115    114     11                         114_dare_jerk_fuck_portion
# 116    115     11                 115_repair_phone_clickaway_verizon
# 117    116     11                       116_vent_dryer_cleaning_dora
# 118    117     11  117_publish_place_waystoovercomeyourdepression...
# 119    118     11               118_pinterest_arvin_donguines_lennor
#
#                                         Representation  \
# 0      [the, to, and, it, this, in, that, of, you, rt]
# 1    [user, account, gander, tabletsrental, allfxbr...
# 2    [following, twitter, hello, thank, say, anytim...
# 3    [rt, this, crying, password, im, boom, so, my,...
# 4    [depression, treatments, overcome, treatment, ...
# ..                                                 ...
# 115  [dare, jerk, fuck, portion, hell, cares, how, ...
# 116  [repair, phone, clickaway, verizon, redwood, s...
# 117  [vent, dryer, cleaning, dora, mount, rosa, gra...
# 118  [publish, place, waystoovercomeyourdepression,...
# 119  [pinterest, arvin, donguines, lennor, patrick,...
#
#                                    Representative_Docs
# 0    [how can people even put up with me, its like ...
# 1                              [user talk, user, user]
# 2    [is now following me on twitter thank you say ...
# 3    [rt oh my god this is me and im so sorry, rt i...
# 4    [healthy living finding new treatments for dep...
# ..                                                 ...
# 115      [ok how dare you, how dare you, how dare you]
# 116  [clickaway redwood city verizon store phone re...
# 117  [mount dora dryer vent cleaning, mount dora dr...
# 118  [publish place wouldyoufeeldepressedreadthisin...
# 119  [patrick lennor on pinterest, arvin donguines ...
#
# [120 rows x 5 columns]

# %% [markdown]
# Clusters from perfoming BERTopic on mental health data

# %%
for i in range(num_topics):
  print("\n== Representative documents in cluster #", i)
  print(topic_model.get_representative_docs(i))
# Out:
# == Representative documents in cluster # 0
# ['user talk', 'user', 'user']
#
# == Representative documents in cluster # 1
# ['is now following me on twitter thank you say hello any', 'is now following me on twitter thank you say hello any', 'is now following me on twitter thank you say hello anytime i am a real person']
#
# == Representative documents in cluster # 2
# ['rt oh my god this is me and im so sorry', 'rt is that you', 'rt b and s']
#
# == Representative documents in cluster # 3
# ['healthy living finding new treatments for depression depression treatments', 'depression treatments', 'depression treatments']
#
# == Representative documents in cluster # 4
# ['trump quotes putin in tweet slamming clinton democrats has more positive things to say about putin than opponents no', 'putin ordered hacking to help trump intelligence report says via', 'does the word putin mean anything to you of trump voters like putin you know the']
#
# == Representative documents in cluster # 5
# ['why is the propagandist for trump joe scarborough spending most of his show this morning trying to cast', 'like fox andy amp phil wanted to cater to altright joe scarborough good example propaganda for trump', 'who do you think won the propaganda war for trump morning joe or rt']
#
# == Representative documents in cluster # 6
# ['rt malay language is really cool like instead of saying im not really sure about the things im saying we say kot yes thr', 'tak ada ke sugar daddy yang tak involve physical touch mostly nak physical astaga', 'tak sure her friend tu ke or one of her acquaintances there in university girl tu parents dia pun duduk new zealand']
#
# == Representative documents in cluster # 7
# ['if i delete my tweet nobody will ever notice', 'now this is a tweet that i can agree to', 'tweet tweet tweet until you tweet yourself to sleep kinda like a hot bottle of milk']
#
# == Representative documents in cluster # 8
# ['you know what im gonna take it easy and start small buy a lightsaber thats cheaper then save up money to buy the one that costs', 'it is a lightsaber', 'rt lightsaber']
#
# == Representative documents in cluster # 9
# ['but i dont have a girlfriend', 'rt i hate how much of a sucker i am for fake dating aus like theyre so predictable but im here for it', 'well hey as long as i have zyl i dont care about what happens to anyone elses relationship']
#
# == Representative documents in cluster # 10
# ['rt wishing you all a merry christmas', 'oh and happy hanukkah and merry christmas i hope all of yall have wonderful days and that ur family members are kind', 'rt happy new year']
#
# == Representative documents in cluster # 11
# ['i refuse to watch it honestly i can just tell its bad this series deserved a netflix show listen', 'theres a show i need to watch it', 'god ok so im watching emerald city and this show is so gorgeous like ive gasped so many times and im not even half way through the first']
#
# == Representative documents in cluster # 12
# ['bellamy is in love with clarke goodnight', 'rt clarke amp bellamy', 'rt bellamy amp clarke']
#
# == Representative documents in cluster # 13
# ['talk business exercisecanhelpmanageandtreatdepression', 'talk business takealookatthisarticleondepressionthatoffersmanysuperbsuggestions', 'talk business wouldyoufeeldepressedreadthisinformativearticle']
#
# == Representative documents in cluster # 14
# ['thankyou so much', 'thankyou so much', 'thankyou so much']
#
# == Representative documents in cluster # 15
# ['rt what makes riverdale so massively important is that it never pits betty and veronica against each other for archie', 'rt kj apa on playing archie i knew it would be a big responsibility to create the best version of him riverdale tca', 'wait so ok why did riverdale do that to kj']
#
# == Representative documents in cluster # 16
# ['laser center yonkers', 'laser center yonkers', 'laser center yonkers']
#
# == Representative documents in cluster # 17
# ['so when you wear perfumes youre not only trying to smell good you want to attract people into smelling you as well', 'ok let me go eat i smell some good ass food', 'thats why some girls like to smell boys armpits now im not pointing fingers here but ive seen tweets of girls wanting to bau tiak']
#
# == Representative documents in cluster # 18
# ['desperate attempt to stop truth from escaping into the public notice if enough citizens support truth', 'well stop mocking him in yrs when you quiet lying we might think about it when you lied today about the sprint deal old news lie', 'truth']
#
# == Representative documents in cluster # 19
# ['sagefrog marketing group llc', 'construction llc', 'construction llc']
#
# == Representative documents in cluster # 20
# ['im so happy i cant sleep', 'i dont sleep', 'im so happy i cant sleep']
#
# == Representative documents in cluster # 21
# ['buuuut girls can play with makeup and boys cant so sorry mate were gonna stuck being ugly for the rest of our lives', 'cant find a single picture of me where i look manly the manly looking pictures are the ones where im shirtless fml', 'if i were a makeup guru ofc id be looking for girls who like to do makeup tutorials if i were an ustaz id find another ustaz']
#
# == Representative documents in cluster # 22
# ['philadelphia childrens hospital bans dietary supplements depression treatments', 'what is aloe vera medical news today depression treatments', 'what is aloe vera medical news today depression treatments']
#
# == Representative documents in cluster # 23
# ['no yes', 'yes this', 'yes yes yes']
#
# == Representative documents in cluster # 24
# ['trump says he never mocked a disabled reporter heres the video showing he did meryl streep for president', 'trumps press secretary begs the american people to stop mocking donald trump via neverltneverltnever', 'trumps press secretary begs the american people to stop mocking donald trump via']
#
# == Representative documents in cluster # 25
# ['a manly albino', 'she doesnt look like an albino though o', 'this account is handled by albino bot albino bot retweets everything with the word albino in it']
#
# == Representative documents in cluster # 26
# ['leave depression behind now with these hints article teller', 'how to live a depression free life article teller', 'easy things you have to know about depression article teller']
#
# == Representative documents in cluster # 27
# ['rt news dylan is officially finished with teen wolf he had his last day on set yesterday and tyler came to support him', 'rt tyler posey on set of teen wolf', 'rt dylan obrien and tyler posey on set of teen wolf']
#
# == Representative documents in cluster # 28
# ['more jedi body study for tonight procrastinating my supposed time to study for my final exams', 'me when i realize that i havent studied for my final exam', 'is it bad that i still havent studied anything for my final exam']
#
# == Representative documents in cluster # 29
# ['is it because youre black', 'but i dont have a black', 'be black']
#
# == Representative documents in cluster # 30
# ['how gardening provides relief from stress stealth grow box hydroponic magic', 'some of the most common health benefits of gardening stealth grow box hydroponic magic', 'common health benefits of gardening stealth grow box hydroponic magic']
#
# == Representative documents in cluster # 31
# ['rt mac owners will be glad to pay for hours to play pc games using geforce now you guys pay twice as much for everything', 'rt nvidia just announced geforce now lets you stream games from the cloud even lets you play all your steam games on a mac htt', 'launch steam to launch the game to launch uplay to launch steam to actually launch the game um yeah no bye']
#
# == Representative documents in cluster # 32
# ['rt why hasnt chloe bennet been casted in an upcoming star wars movie yet im a good person i deserve it and chloe des', 'rt update crystal said lydia was one of the most important people in allisons life she literally died for her nemetonita', 'rt iris breathes barry shes strong shes passionate shes smart shes tough and shes an adult and shes tough she']
#
# == Representative documents in cluster # 33
# ['actually no if you wanna kill me please do it quickly i dont want a slow death or do i', 'funny thing about death is the fact that you randomly want to contact the person but then you remember eh dah takda', 'nashid i like to be reminded of god and death and the beauty of the afterlife at all times']
#
# == Representative documents in cluster # 34
# ['local seo citations or business listing', 'local seo citations or business listing', 'local seo citations or business listing']
#
# == Representative documents in cluster # 35
# ['daly city carpet cleaning experts', 'userresidential carpet cleaning', 'userresidential carpet cleaning']
#
# == Representative documents in cluster # 36
# ['rt happy birthday to this beautiful soul', 'happy birthday', 'rt happy birthday to this beautiful soul']
#
# == Representative documents in cluster # 37
# ['innovation dental center', 'advanced dental care of ridgewood', 'advanced dental care of ridgewood']
#
# == Representative documents in cluster # 38
# ['attend the inauguration approves of trump dont attend and suffer negative comments for a while go', 'donald trumps inauguration want to see what a demagogue looks like bully dont condemn any american for this', 'in charts and can trump deliver in chart put this in every face that voted for trump']
#
# == Representative documents in cluster # 39
# ['rt never lend money or do business w friends unless youre willing to risk your fri', 'actually never lend money to friends unless you dont want them as a friend no moe they were never your friends to begin with', 'if i take my friends shift today ill start a day streak until my next break and i dont want to do it but i need the money god why']
#
# == Representative documents in cluster # 40
# ['cat litter source', 'cat litter source', 'rt i need this cat in my life']
#
# == Representative documents in cluster # 41
# ['haha alrighty thanks', 'alrighty thankyou', 'alrighty thanks for the input']
#
# == Representative documents in cluster # 42
# ['also that music that was some good shit and i cant believe im trying to revive this meme but thats some goooooood shit', 'halsey is dropping new music this year everyone else go home im already claiming this as my favorite album of the year', 'the gag isidk many drake songs so that was lowkey a legit question']
#
# == Representative documents in cluster # 43
# ['rt picture new picture of adelaide she looks beautiful reign lltq', 'rt pictures adelaide via instagram stories adelaidekane', 'rt pictures adelaide via instagram reign adelaidekane']
#
# == Representative documents in cluster # 44
# ['rt waiting for shadowhunters like lol nomakeup idontcare shadowhuntersseason', 'rt izzy clary shadowhunters', 'shadowhunters is back tomorrow yall']
#
# == Representative documents in cluster # 45
# ['local appliance repair experts', 'ac and heating repair installation naperville', 'ac and heating repair installation naperville']
#
# == Representative documents in cluster # 46
# ['depression treatments south africa violence in pregnancy and hiv in south africa', 'postpartum depression depression treatments', 'overcome depression how to overcome depression during pregnancy tips informationanalytic agency newsam']
#
# == Representative documents in cluster # 47
# ['depression on pinterest pins', 'depression on pinterest', 'depression on pinterest']
#
# == Representative documents in cluster # 48
# ['allentown moving companies', 'allentown moving companies', 'allentown moving companies']
#
# == Representative documents in cluster # 49
# ['rt she took a little piece of all of us with her toosoon', 'rt she took a little piece of all of us with her toosoon', 'shes cute']
#
# == Representative documents in cluster # 50
# ['i told her many times that the kids not behaving normally like he has some form of autism even if he doesnt wouldnt checking be better', 'somewhat amazed with my parents zero tolerance for lateness policy its either be ready on time or be ready to be left behind', 'hands up to the parents with disableddifferently abled kids who treat their kids with great patience and understanding']
#
# == Representative documents in cluster # 51
# ['so so cute', 'this is so cute', 'so cute']
#
# == Representative documents in cluster # 52
# ['law passed gop presidents in office years since passed and they di', 'what a mix gop crazy president gop stupid senate crooked house', 'gop talked six years votes to repeal in house never knew the cost incompetent slugs']
#
# == Representative documents in cluster # 53
# ['hey djt whats this all about come on', 'turns out youre a lair drt is a lair and both are evil', 'you putz since djt cares for no one but djt nothing you declare can happen he has to care abou']
#
# == Representative documents in cluster # 54
# ['she talk isyourspousedepressedwaysitispossibletohelp', 'i havent taken it yet shes having some personal problems and i asked her if she was going in and she said no so like im', 'asked my professor what shes going to do postretirement she said she wanted to write a book turns out she wrote buku text form amp']
#
# == Representative documents in cluster # 55
# ['houston greens', 'bmw of houston north in the woodlands', 'bmw of houston north in the woodlands']
#
# == Representative documents in cluster # 56
# ['circles end depression therapy who had a great winter mental health', 'circles end depression therapy feeling depressed animalassisted therapy could', 'circles end depression therapy']
#
# == Representative documents in cluster # 57
# ['dunce support for a proven racist because he is from alabama hes from altright he o', 'george wallace jeff sessions america thats fox altright pushing fora s alabama segregated scho', 'the altright fox amp brietbart are pushing for an america of s if you want to live in a s state alabama wi']
#
# == Representative documents in cluster # 58
# ['franklin and the evangelicals put you on top now lets see what jesus says do', 'but he speaks for christ evangelicals for benny israel has the problem now that well have on jan', 'most know why evangelicals dont like him seen up closehatred many evangelical churches but i kn']
#
# == Representative documents in cluster # 59
# ['rt darth plagueis master to darth sidious arguably most powerful sith alchemist most speculated fate in star wars histo', 'rt this was last night at the star wars rogue one movie premiere of damn lit', 'star wars rogue one was beautiful']
#
# == Representative documents in cluster # 60
# ['they shouldnt be pictured together daylight amp dark honest amp truthful vs dark amp evil', 'spicer is deplorable amp despicable', 'spicer is deplorable amp despicable']
#
# == Representative documents in cluster # 61
# ['rt drawing with my niece who did not like this drawing and made me draw her lebron james to make up for it', 'quick sketch', 'quick sketch']
#
# == Representative documents in cluster # 62
# ['garage door repair redondo beach', 'usergarage door repair redondo beach', 'garage door repair redondo beach']
#
# == Representative documents in cluster # 63
# ['i love my body even more now also love your body too hug me hoe mengambil kesempatan only if youre rich though', 'rt np i love you too im glad i met you too i hope is nothing but happiness and greatness for u', 'thank you luci im so glad i met you i love you']
#
# == Representative documents in cluster # 64
# ['global education academy', 'global education academy', 'global education academy']
#
# == Representative documents in cluster # 65
# ['i have a chinese friend who had chest hair like literal thick chest hair', 'if youre a guy would you perm your own hair kerintingkan rambut lurus from boring asian hair', 'god i hope he cuts her hair literally someone anyone cut her hair']
#
# == Representative documents in cluster # 66
# ['dont think for a second that broken people are unrepairable the universe led you to them for a reason maybe you can fix whatevers broken', 'when you look at broken people do you ever stop to think that maybe they were broken by someone else', 'when you look at broken people do you ever stop to think that maybe youre broken as well']
#
# == Representative documents in cluster # 67
# ['southington inn motor lodge southington ct', 'southington inn motor lodge southington ct', 'southington inn motor lodge southington ct']
#
# == Representative documents in cluster # 68
# ['im so pressed vine is ending before i have the chance to learn to edit i had so many ideas', 'omg i saw that scottstiles vine to knocking on heavens door while looking for a totally different vine bye', 'go d vine is so dead im sad']
#
# == Representative documents in cluster # 69
# ['to m call out sins against america tell all dont sin against america respect sinners against ame', 'rachel one last item sins against america sin against america or dont sin against american', 'sins against america label those that sin against america also dont sin against america']
#
# == Representative documents in cluster # 70
# ['cerulean advanced fitness and wellness', 'cerulean advanced fitness and wellness', 'cerulean advanced fitness and wellness']
#
# == Representative documents in cluster # 71
# ['sin against america committed by sessions for many years hes is a disciple of john calhoun amp george wallacera', 'not his history a disciple of john c calhoun amp george wallace hes committed sin against ameri', 'john c calhoun disciple loved geo wallace a racist']
#
# == Representative documents in cluster # 72
# ['winter blues lack of sun often leads to depression my champlain valley fox amp abc overcome depression', 'a southern belle from texas depression plus your overall emotional wellbeing', 'overcome depression winter season blues ways to enhance mood plus energy']
#
# == Representative documents in cluster # 73
# ['oh god', 'oh my god', 'oh my god']
#
# == Representative documents in cluster # 74
# ['the sunshine avenue motley crue promise to never reunite after next tour', 'the sunshine avenue jesse eisenberg is lex luthor jeremy irons playing alfred in batman vs forbes', 'the sunshine avenue jesse eisenberg is lex luthor jeremy irons playing alfred in batman vs forbes']
#
# == Representative documents in cluster # 75
# ['national concrete accessories victoria', 'national concrete accessories edmonton', 'national concrete accessories edmonton']
#
# == Representative documents in cluster # 76
# ['a lack of knowledgeso tell me where the illegal bush wars expense is listedoff', 'report trumps secretary of state pick did illegal business with iran', 'report trumps secretary of state pick did illegal business with iran']
#
# == Representative documents in cluster # 77
# ['rt the bee movie but every time its altered and uploaded to youtube its removed on legal grounds', 'bee movie is gonna be on netflix next month', 'bee movie is gonna be on netflix next month']
#
# == Representative documents in cluster # 78
# ['stop', 'stop', 'stop']
#
# == Representative documents in cluster # 79
# ['mood', 'mood', 'mood']
#
# == Representative documents in cluster # 80
# ['ha ha if i wasnt so conflicted and had bought it before our currency went to the crapper i wouldve been able to afford both', 'came back to the shop the next day i bought the money to buy it i asked the same guy again berapa eh benda ni', 'the otomatone itself costs rm the company states that its free shipping i check out my cart theyre charging me rm tf u scammin me']
#
# == Representative documents in cluster # 81
# ['unknown title', 'unknown title', 'unknown title']
#
# == Representative documents in cluster # 82
# ['my lrt i was truly just waiting for someone to say shit about taylor yall never disappoint', 'rt taylor swift cant sing', 'rt when will taylor swift']
#
# == Representative documents in cluster # 83
# ['sing loud changes on swift products for foods for depression', 'sing loud the hard battle howto fight depression', 'sing loud the best methods to overcome depression and be happy']
#
# == Representative documents in cluster # 84
# ['ginny baker bad girls audios mine ib ultraheda cc janesxwonderland a woman vine by', 'rt legendary runway walk cc queen stydia ac bling audios dt chiz vine by holy moose bio', 'veronica lodge cc celestial ac crazed audios vine by']
#
# == Representative documents in cluster # 85
# ['north shore plumbing', 'north shore plumbing', 'north shore plumbing']
#
# == Representative documents in cluster # 86
# ['holy crap this company that makes custom sabers lets you design them yourself and then they build it for you', 'i joined one of the custom sabers group sorry kurang info dia jual ni body kosong without electronics kena pasang sendiri', 'remember the custom sabers company that i told you about the one that i said produced high quality sabers but take up to months']
#
# == Representative documents in cluster # 87
# ['knox family law specialist', 'knox family law specialist', 'knox family law specialist']
#
# == Representative documents in cluster # 88
# ['parks', 'foxfire mountain adventure park', 'foxfire mountain adventure park']
#
# == Representative documents in cluster # 89
# ['dexters tower bridge estate agents', 'dexters st johns wood estate agents', 'dexters st johns wood estate agents']
#
# == Representative documents in cluster # 90
# ['right now i need to find a white shirt chino pants a black sweater a backpack need to put the kitties inside the backpack amp pose andy', 'rt yrold harajuku duo in dark minimalist styles w comme des garcons coteampciel azul sly amp dr martens', 'harajuku is a place in japan where people does all these gothicfuturistic fashion with brightly colored clothes amp hairs its cool']
#
# == Representative documents in cluster # 91
# ['of exxon oil drilling rights in russia usa sanctions stopped drilling no drilling s', 'of russia oil drilling options in russia in us sanctions stopped drilling up to', 'of exxon drilling options in russia in us sanctions in stopped drilling']
#
# == Representative documents in cluster # 92
# ['that being said youll know when the time is right for you so take it easy were all trying to be better muslims', 'aiyo people before you slide into my dms at least give salaam first im a muslim by nature okay lets all try our best to be good muslims', 'people do know muslims dont actually burn when they touch pigs blood right oh except radical malay muslims tha']
#
# == Representative documents in cluster # 93
# ['well yes i already got over my addiction with buying designer toys sticking to figmas and nendoroids again', 'not sex toys god', 'rt i wish i could buy all the toys at toys r us']
#
# == Representative documents in cluster # 94
# ['disregard of constitution country amp citizens if candidate for cabinet is not properly vetted could be in big tro', 'sane citizens must stand up come on we let this guy be our president come on you', 'i believe this guy bypassed our president recently and went directly to congress who will be the president i']
#
# == Representative documents in cluster # 95
# ['simple relaxation techniques to help reduce stress', 'ways to stress less at work', 'relaxation techniques to help reduce stress']
#
# == Representative documents in cluster # 96
# ['property and spain', 'bikes barcelona rental', 'bikes barcelona rental']
#
# == Representative documents in cluster # 97
# ['bearcom', 'bearcom colorado springs', 'bearcom colorado springs']
#
# == Representative documents in cluster # 98
# ['rt president obama ends his years in the office with the same message that helped him get there obamafarewell', 'eight years later the economy and president obamas legacy via of a kind never see likesofhim again', 'eight years later the economy and president obamas legacy via']
#
# == Representative documents in cluster # 99
# ['rt why is no one talking about ross bulter aka reggie mantle my mans look fine as hell', 'hahaha hopefully ill look just as fine as him when i reach his age', 'wait come to think of it people mustve thought he was a boyfriend or something kan years older than me taller handsomer oh god']
#
# == Representative documents in cluster # 100
# ['hold on mika your reaction seems to show you may have personal skin in this game your panic comes acros', 'i understand he amp mika are there often especially mika', 'hey phil amp andywhat part did you play in this doubt joe amp mika did this without your approval cover ups']
#
# == Representative documents in cluster # 101
# ['apps can help relieve stress anxiety sydney morning herald depression treatments', 'apps can help relieve stress anxiety sydney morning herald depression treatments', 'overcome depression sleep therapy to treat depression sydney morning herald']
#
# == Representative documents in cluster # 102
# ['dleee thsis befor i dive jnto the tag', 'em scuse me hoe you havent given me anythin at all', 'i dont even need you hoes attention dey cheap af']
#
# == Representative documents in cluster # 103
# ['wait whats your full name though', 'friend gives me email with his full name me replies awww thats so cute i didnt know your last name was suguma can i call you that', 'peace is my stage name my full name is peace off ahsjbajahahs funniest joke ive come up with in awhile']
#
# == Representative documents in cluster # 104
# ['angels repair center', 'angels repair center', 'angels repair center']
#
# == Representative documents in cluster # 105
# ['rt i am raven', 'rt i would die for raven reyes', 'rt i would die for raven reyes']
#
# == Representative documents in cluster # 106
# ['idk my first instinct was moretz bc i was talking to u but now that u say that their lengths are similar i love', 'i also genuinely have no preference bc i will love whomever u pick im just trying to decide who im using', 'everyones picking b so ill go with that']
#
# == Representative documents in cluster # 107
# ['go green glazing geelong vic', 'go green glazing geelong vic', 'go green glazing geelong vic']
#
# == Representative documents in cluster # 108
# ['blocked', 'blocked', 'blocked']
#
# == Representative documents in cluster # 109
# ['william stanton md', 'william stanton md', 'william stanton md']
#
# == Representative documents in cluster # 110
# ['eh ok im still mad that none of my apple pencils work cb how do i return an apple product if i bought it online sheesh', 'no its called the apple pencil', 'medibang paint on an ipad pro with an apple pencil the software is free to download would highly recommen']
#
# == Representative documents in cluster # 111
# ['junk hauled today', 'junk hauled today', 'junk hauled today']
#
# == Representative documents in cluster # 112
# ['pennsylvania nov unemployment rate did you know that you people got', 'nov unemployment penn mich ohio wis check in nov', 'nov unemployment rate mich penn ohio wis this info available to you']
#
# == Representative documents in cluster # 113
# ['studentservicesq', 'seal tax service', 'seal tax service']
#
# == Representative documents in cluster # 114
# ['ok how dare you', 'how dare you', 'how dare you']
#
# == Representative documents in cluster # 115
# ['clickaway redwood city verizon store phone repair computer repair', 'clickaway redwood city verizon store phone repair computer repair', 'clickaway redwood city verizon store phone repair computer repair']
#
# == Representative documents in cluster # 116
# ['mount dora dryer vent cleaning', 'mount dora dryer vent cleaning', 'mount dora dryer vent cleaning']
#
# == Representative documents in cluster # 117
# ['publish place wouldyoufeeldepressedreadthisinformativearticle', 'publish place waystoovercomeyourdepression', 'publish place waystoovercomeyourdepression']
#
# == Representative documents in cluster # 118
# ['patrick lennor on pinterest', 'arvin donguines on pinterest', 'v k on pinterest']
#
# == Representative documents in cluster # 119
# ['does that sound strange to you talking silly dont you think', 'ady my friend here asks are you serious', 'well no but i assumed as such smh i swear one of these days']

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('user', 0.03914452219317539),
#  ('account', 0.02668260255799135),
#  ('gander', 0.02443909698267449),
#  ('tabletsrental', 0.02443909698267449),
#  ('allfxbrokers', 0.019373239771537244),
#  ('petraguardcoatings', 0.019373239771537244),
#  ('userasappartsunlimited', 0.019373239771537244),
#  ('userhdfworm', 0.013898007974381744),
#  ('davistrimming', 0.013898007974381744),
#  ('userboisewindowtinting', 0.013898007974381744)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f2200d9-44f0-4370-86b2-ce23634ffb79" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f2200d9-44f0-4370-86b2-ce23634ffb79")) {                    Plotly.newPlot(                        "5f2200d9-44f0-4370-86b2-ce23634ffb79",                        [{"customdata":[[0,"user | account | gander | tabletsrental | allfxbrokers",604],[1,"following | twitter | hello | thank | say",330],[2,"rt | this | crying | password | im",230],[3,"depression | treatments | overcome | treatment | health",223],[4,"putin | trump | russia | russian | putins",210],[5,"joe | propaganda | msnbc | scarborough | fox",143],[6,"malay | tak | dia | malaysia | language",98],[7,"tweet | twitter | facebook | tweets | tweeting",93],[8,"lightsaber | lightsabers | buy | saber | that",75],[9,"relationship | girlfriend | dating | girls | bdsm",71],[10,"christmas | year | happy | merry | love",66],[11,"show | watch | shows | im | emerald",61],[12,"bellamy | clarke | blake | hes | rt",56],[13,"business | talk | newsvine | development | personal",52],[14,"thankyou | much | amazing | support | thanks",47],[15,"riverdale | kj | archie | betty | veronica",45],[16,"clinic | center | chiropractic | yonkers | physicaltherapyisr",44],[17,"smell | eat | eating | bau | girls",44],[18,"truth | lie | lies | lying | about",43],[19,"llc | inc | group | construction | contractor",43],[20,"sleep | goodnight | nap | hours | slept",41],[21,"manly | makeup | ugly | selfies | mirror",40],[22,"depression | treatments | overcome | vera | aloe",39],[23,"yes | yesh | well | wait | sense",38],[24,"trump | mocking | via | meryl | streep",37],[25,"albino | albinos | whether | an | naked",37],[26,"teller | article | these | advice | depression",36],[27,"tyler | dylan | shelley | posey | wolf",35],[28,"final | exam | exams | study | paper",35],[29,"black | white | colour | dye | skin",35],[30,"catering | hydroponic | stealth | gardening | safety",33],[31,"game | steam | launch | play | games",33],[32,"lydia | shes | barry | iris | her",33],[33,"death | die | afterlife | morbid | hell",33],[34,"citations | seo | website | links | google",32],[35,"cleaning | carpet | removal | cleaners | blackhead",32],[36,"birthday | happy | bday | th | wonderful",31],[37,"dental | advanced | dentistry | dentist | las",31],[38,"trump | inauguration | trumps | voters | charts",30],[39,"money | lend | bank | friends | cash",30],[40,"cat | pet | litter | dog | cats",28],[41,"alrighty | input | thanks | thankyou | alright",28],[42,"audio | song | songs | dhamaka | lyrics",28],[43,"adelaide | lltq | pictures | margot | instagram",27],[44,"shadowhunters | shadowhuntersseason | shadowhunterschat | clary | season",27],[45,"heating | electrical | repair | appliance | killawatt",27],[46,"depression | overcome | pregnancy | postpartum | postnatal",27],[47,"pinterest | pins | on | depression | relapse",26],[48,"moving | companies | okc | locksmith | affordable",26],[49,"shes | she | her | cute | pretty",26],[50,"parents | children | kids | autistic | autism",25],[51,"cute | so | tiny | omg | fuck",25],[52,"gop | repeal | law | house | years",25],[53,"djt | lair | drt | sambil | bertweet",25],[54,"she | talk | shes | asked | theimportantpointsandfastsuggestionsaboutwaystogetreducedepression",25],[55,"houston | bmw | motorcycle | locations | indian",24],[56,"circles | end | therapy | depression | syndrome",24],[57,"altright | alabama | kkk | white | black",24],[58,"evangelicals | evangelical | jesus | israel | pastor",23],[59,"star | wars | darth | rogue | rey",23],[60,"amp | deplorable | evil | old | insightful",23],[61,"sketch | draw | drawing | quick | sketchy",23],[62,"door | garage | usergarage | repair | doors",23 ...

# %% [markdown]
# From these clusters - we have used ChatGPT to filter mental health keywords from the cluster content
#
# 1. Initiated prompts to chatgpt to only take into consideration clusters that talk/relate to/similar to mental health topics
#
# 2. From this list of clusters, prompted chatgpt to extract individual keywords from aforemention cluster list that talk/relate to/similar to mental health topics

# %% [markdown]
# After filtering done by ChatGPT which was done many times to get higher freq of mental health related keywords from our data
#
# bertopic_keywords = {
#
#     2: ['depression', 'depression treatments'],
#     7: ['broken people', 'unrepairable', 'fix', 'broken'],
#     15: ['talk business adviceconcerningyourfightwithdepression', 'talk business adviceandadviceoncopingwithdepression', 'talk business wouldyoufeeldepressedreadthisinformativearticle'],
#     30: ['leave depression behind now with these hints article teller', 'easy things you have to know about depression article teller', 'how to live a depression free life article teller'],
#     50: ['circles end depression therapy who had a great winter mental health', 'circles end depression therapy feeling depressed animalassisted therapy could', 'circles end depression therapy'],
#     69: ['overcome depressive disorders beating the wintertime blues seasonal affective disorder', 'overcome depression winter season blues ways to enhance mood plus energy', 'winter blues lack of sun often leads to depression my champlain valley fox amp abc overcome depression'],
#     91: ['simple relaxation techniques to help reduce stress', 'relaxation techniques to help reduce stress', 'ways to stress less at work'],
#     98: ['apps can help relieve stress anxiety sydney morning herald depression treatments', 'overcome depression sleep therapy to treat depression sydney morning herald', 'apps can help relieve stress anxiety sydney morning herald depression treatments'],
#     103: ['sing loud changes on swift products for foods for depression', 'sing loud the hard battle howto fight depression', 'sing loud the best methods to overcome depression and be happy']
# }

# %%
bertopic_keywords = {

2: ['depression', 'depression treatments'],
7: ['broken people', 'unrepairable', 'fix', 'broken'],
15: ['talk business adviceconcerningyourfightwithdepression', 'talk business adviceandadviceoncopingwithdepression', 'talk business wouldyoufeeldepressedreadthisinformativearticle'],
30: ['leave depression behind now with these hints article teller', 'easy things you have to know about depression article teller', 'how to live a depression free life article teller'],
50: ['circles end depression therapy who had a great winter mental health', 'circles end depression therapy feeling depressed animalassisted therapy could', 'circles end depression therapy'],
69: ['overcome depressive disorders beating the wintertime blues seasonal affective disorder', 'overcome depression winter season blues ways to enhance mood plus energy', 'winter blues lack of sun often leads to depression my champlain valley fox amp abc overcome depression'],
91: ['simple relaxation techniques to help reduce stress', 'relaxation techniques to help reduce stress', 'ways to stress less at work'],
98: ['apps can help relieve stress anxiety sydney morning herald depression treatments', 'overcome depression sleep therapy to treat depression sydney morning herald', 'apps can help relieve stress anxiety sydney morning herald depression treatments'],
103: ['sing loud changes on swift products for foods for depression', 'sing loud the hard battle howto fight depression', 'sing loud the best methods to overcome depression and be happy']
}

# %% [markdown]
# ###**SBERT**
#
# Training model on Mental Health top 5 user data to research mental health related keywords

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
pip install sentence-transformers scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer

# Create SBERT embeddings
embedder = SentenceTransformer('all-MiniLM-L6-v2')
sbert_embeddings = embedder.encode(docs)

# KMeans clustering on SBERT embeddings
K = 10
sbert_model = KMeans(n_clusters=K, random_state=0)
sbert_model.fit(sbert_embeddings)

# %%
# Print cluster sizes
def print_cluster_sizes(model):
    cnt_per_cluster = {}
    for c in model.labels_:
        cnt_per_cluster[c] = cnt_per_cluster.get(c, 0) + 1
    print(cnt_per_cluster)

print_cluster_sizes(sbert_model)

# %%
def print_docs_closest_to_centroids_sbert(model, vec, n):
    K = len(model.cluster_centers_)

    for j in range(K):
        d = model.transform(vec)[:, j]  # transform all docs to cluster-distance space
        idx = np.argsort(d)[:n]  # find n docs closest to centroid

        c_idx = [i for i, label in enumerate(model.labels_) if label == j]  # find the index of all docs in cluster j
        print('\n\n======cluster #', j, ', cluster size:', len(c_idx))

        for i in idx:
            if i < len(docs) and i in c_idx:
                print(docs.iloc[i])  # Assuming 'docs' is the original DataFrame column
            else:
                print('[Index Error] Doc index out of range or not in the cluster:', i)

# %% [markdown]
# Clusters from perfoming SBert on mental health data

# %%
# Use the modified function
print_docs_closest_to_centroids_sbert(sbert_model, sbert_embeddings, 5)

# %% [markdown]
# From these clusters - we have used ChatGPT to filter mental health keywords from the cluster content
#
# 1. Initiated prompts to chatgpt to only take into consideration clusters that talk/relate to/similar to mental health topics
#
# 2. From this list of clusters, prompted chatgpt to extract individual keywords that talk/relate to/similar to mental health topics
#
# 3. Through several rounds of filtering conducted by ChatGPT on our command, we worked diligently to increase the prevalence of mental health-related keywords within our data.

# %% [markdown]
# sbert_keywords = {
#
#     1: ['trust', 'uglier', 'bothers', 'pretty', 'girls', 'nude', 'photoshoots'],
#     3: ['lonely', 'hollow', 'purpose', 'grateful'],
#     5: ['money', 'buy', 'design', 'save', 'cash', 'order', 'electronics', 'changing', 'colours', 'confused', 'emailed', 'reply', 'checking', 'designs'],
#     6: ['lightsabers', 'lightsaber', 'look', 'designs', 'start', 'small', 'buy', 'cheaper', 'save', 'money'],
#     9: ['obsessed', 'stalking', 'broke', 'house', 'bam', 'crush', 'serial', 'killer', 'thank', 'god', 'came', 'life'],
# }

# %% [markdown]
# Taking keywords into consideration

# %%
sbert_keywords = {
    1: ['trust', 'uglier', 'bothers', 'pretty', 'girls', 'nude', 'photoshoots'],
    3: ['lonely', 'hollow', 'purpose', 'grateful'],
    5: ['money', 'buy', 'design', 'save', 'cash', 'order', 'electronics', 'changing', 'colours', 'confused', 'emailed', 'reply', 'checking', 'designs'],
    6: ['lightsabers', 'lightsaber', 'look', 'designs', 'start', 'small', 'buy', 'cheaper', 'save', 'money'],
    9: ['obsessed', 'stalking', 'broke', 'house', 'bam', 'crush', 'serial', 'killer', 'thank', 'god', 'came', 'life'],
}

# %% [markdown]
# ###**LDA**
#
# Training model on Mental Health top 5 user data to research mental health related keywords

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pandas as pd
import re
import string
import spacy
from collections import Counter

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
docs

# %%
# TF-IDF vectorization
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(docs)

# %%
no_topics = 20
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=10, learning_method='online', learning_offset=50., random_state=0)
lda_z = lda.fit_transform(tfidf)

no_top_words =  10 # Specify the number of top words for each topic

# %%
feature_names = tfidf_vectorizer.get_feature_names_out()

display_topics(lda, feature_names, no_top_words)

# Extract keywords from the topics
feature_names = tfidf_vectorizer.get_feature_names_out()
keywords = []

for topic_idx, topic in enumerate(lda.components_):
    topic_keywords = [feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]
    keywords.extend(topic_keywords)

# %% [markdown]
# lda_keywords = {
#
#     1: ['depression', 'symptoms'],
#     3: ['cry', 'sad', 'fight', 'love'],
#     4: ['depression', 'treatments'],
#     5: ['sad', 'kids', 'fight', 'love', 'disease', 'like', 'campaign', 'little', 'poor', 'person', 'stories', 'artists', 'darkness', 'heartbreaking', 'upgrade', 'understanding', 'cold', 'life', 'sadly', 'insane', 'spelling', 'begin'],
#     6: ['happy', 'wish', 'birthday', 'wonderful', 'intense'],
#     7: ['family', 'hell', 'sweet', 'goodnight', 'hope', 'ill'],
#     8: ['depression', 'helped', 'sucked', 'overcoming', 'overcome', 'stigma', 'thoughts', 'manageable', 'hair', 'dead', 'death', 'ready', 'mute', 'mean', 'color', 'tiny', 'moron'],
#     9: ['suicide', 'blues', 'deplorable', 'cure', 'mad', 'rest', 'mess', 'methods', 'absolutely', 'game', 'thugs', 'benefit', 'toy', 'committed', 'swift', 'toys', 'darker', 'boys', 'wit', 'moron', 'ended', 'makeup', 'lover', 'help', 'mocks', 'people', 'heavy'],
# }

# %%
lda_keywords = {
    1: ['depression', 'symptoms'],
    3: ['cry', 'sad', 'fight', 'love'],
    4: ['depression', 'treatments'],
    5: ['sad', 'kids', 'fight', 'love', 'disease', 'like', 'campaign', 'little', 'poor', 'person', 'stories', 'artists', 'darkness', 'heartbreaking', 'upgrade', 'understanding', 'cold', 'life', 'sadly', 'insane', 'spelling', 'begin'],
    6: ['happy', 'wish', 'birthday', 'wonderful', 'intense'],
    7: ['family', 'hell', 'sweet', 'goodnight', 'hope', 'ill'],
    8: ['depression', 'helped', 'sucked', 'overcoming', 'overcome', 'stigma', 'thoughts', 'manageable', 'hair', 'dead', 'death', 'ready', 'mute', 'mean', 'color', 'tiny', 'moron'],
    9: ['suicide', 'blues', 'deplorable', 'cure', 'mad', 'rest', 'mess', 'methods', 'absolutely', 'game', 'thugs', 'benefit', 'toy', 'committed', 'swift', 'toys', 'darker', 'boys', 'wit', 'moron', 'ended', 'makeup', 'lover', 'help', 'mocks', 'people', 'heavy'],
}

# %% [markdown]
# # Master Keywords List
# Combining keywords from topic modeling from 3 models:
#
# 1. BERTopic
# 2. BERT
# 3. LDA

# %%
master_keywords = set()

# Add bertopic keywords to master_keywords
for keywords in bertopic_keywords.values():
    master_keywords.update(keywords)

# Add sbert keywords to master_keywords
for keywords_list in sbert_keywords.values():
    master_keywords.update(keywords_list)

# Add lda keywords to master_keywords
for keywords_list in lda_keywords.values():
    master_keywords.update(keywords_list)


# Convert set to list
master_keywords = list(master_keywords)

# Print the master_keywords list
print(master_keywords)
# Out:
# ['simple relaxation techniques to help reduce stress', 'artists', 'spelling', 'birthday', 'helped', 'depression', 'talk business adviceandadviceoncopingwithdepression', 'overcome', 'deplorable', 'heartbreaking', 'heavy', 'changing', 'wonderful', 'mute', 'help', 'symptoms', 'lightsabers', 'purpose', 'electronics', 'designs', 'circles end depression therapy feeling depressed animalassisted therapy could', 'circles end depression therapy who had a great winter mental health', 'lonely', 'look', 'photoshoots', 'kids', 'love', 'talk business adviceconcerningyourfightwithdepression', 'lover', 'buy', 'start', 'makeup', 'killer', 'fight', 'house', 'design', 'obsessed', 'methods', 'sad', 'reply', 'cash', 'wish', 'toys', 'intense', 'relaxation techniques to help reduce stress', 'depression treatments', 'cure', 'how to live a depression free life article teller', 'understanding', 'broken people', 'sweet', 'mocks', 'nude', 'small', 'easy things you have to know about depression article teller', 'death', 'overcome depression winter season blues ways to enhance mood plus energy', 'leave depression behind now with these hints article teller', 'game', 'circles end depression therapy', 'like', 'talk business wouldyoufeeldepressedreadthisinformativearticle', 'pretty', 'stigma', 'tiny', 'thoughts', 'ways to stress less at work', 'sing loud the hard battle howto fight depression', 'treatments', 'apps can help relieve stress anxiety sydney morning herald depression treatments', 'family', 'broken', 'bothers', 'committed', 'bam', 'cheaper', 'thugs', 'overcome depression sleep therapy to treat depression sydney morning herald', 'begin', 'color', 'fix', 'serial', 'stories', 'hell', 'unrepairable', 'sadly', 'broke', 'rest', 'colours', 'campaign', 'poor', 'overcoming', 'manageable', 'boys', 'hair', 'stalking', 'overcome depressive disorders beating the wintertime blues seasonal affective disorder', 'grateful', 'ready', 'uglier', 'ended', 'wit', 'people', 'moron', 'benefit', 'god', 'lightsaber', 'mess', 'mean', 'save', 'cry', 'toy', 'confused', 'life', 'checking', 'thank', 'cold', 'girls', 'blues', 'absolutely', 'goodnight', 'sucked', 'swift', 'little', 'suicide', 'ill', 'trust', 'crush', 'happy', 'darkness', 'darker', 'insane', 'winter blues lack of sun often leads to depression my champlain valley fox amp abc overcome depression', 'sing loud the best methods to overcome depression and be happy', 'came', 'person', 'disease', 'order', 'hope', 'upgrade', 'dead', 'mad', 'emailed', 'sing loud changes on swift products for foods for depression', 'hollow', 'money']

# %% [markdown]
# Manually rechecking master keywords list- word by word

# %% [markdown]
# master_keywords =
#
# ['cure', 'overcome', 'stigma', 'methods', 'heartbreaking', 'depression', 'love', 'suicide', 'artists', 'intense', 'disease', 'ended', 'changing', 'poor', 'lover', 'ready', 'benefit', 'goodnight', 'absolutely', 'toys', 'happy', 'trust', 'mess', 'purpose', 'understanding', 'girls', 'pretty', 'manageable', 'hair', 'overcoming', 'cold', 'sweet', 'broke', 'thoughts', 'start', 'family', 'mad', 'ill', 'confused', 'heavy', 'boys', 'kids', 'lonely', 'campaign', 'treatments', 'fight', 'little', 'upgrade', 'life', 'mute', 'wish', 'wonderful', 'sad', 'begin', 'helped', 'thugs', 'insane', 'symptoms', 'grateful', 'dead', 'darker', 'people', 'money', 'deplorable', 'bothers', 'obsessed', 'death', 'darkness', 'game', 'birthday', 'blues', 'help', 'rest', 'sadly', 'committed', 'lightsaber', 'moron', 'sucked', 'like', 'small', 'cry', 'toy', 'color', 'nude', 'serial', 'stalking']

# %%
master_keywords = ['cure', 'overcome', 'stigma', 'methods', 'heartbreaking', 'depression', 'love', 'suicide', 'artists', 'intense', 'disease', 'ended', 'changing', 'poor', 'lover', 'ready', 'benefit', 'goodnight', 'absolutely', 'toys', 'happy', 'trust', 'mess', 'purpose', 'understanding', 'girls', 'pretty', 'manageable', 'hair', 'overcoming', 'cold', 'sweet', 'broke', 'thoughts', 'start', 'family', 'mad', 'ill', 'confused', 'heavy', 'boys', 'kids', 'lonely', 'campaign', 'treatments', 'fight', 'little', 'upgrade', 'life', 'mute', 'wish', 'wonderful', 'sad', 'begin', 'helped', 'thugs', 'insane', 'symptoms', 'grateful', 'dead', 'darker', 'people', 'money', 'deplorable', 'bothers', 'obsessed', 'death', 'darkness', 'game', 'birthday', 'blues', 'help', 'rest', 'sadly', 'committed', 'lightsaber', 'moron', 'sucked', 'like', 'small', 'cry', 'toy', 'color', 'nude', 'serial', 'stalking']

# %% [markdown]
# Now we have a master keywords list

# %% [markdown]
# Let's try to filter mental health tweets based on master keywords from original mental health dataset

# %%
# Function to check if a tweet contains any keyword
def contains_keyword(tweet, keywords):
    return any(keyword in tweet for keyword in keywords)

# %%
# Filter tweets
filtered_tweets_all = df[df['post_text'].apply(lambda x: contains_keyword(x, master_keywords))]

# %% [markdown]
# The mental health dataset has 20000 rows

# %%
display(df)
# Out:
#        Unnamed: 0             post_id                    post_created  \
# 0               0  637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1               1  637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 2               2  637749345908051968  Sat Aug 29 22:11:07 +0000 2015
# 3               3  637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4               4  637696327485366272  Sat Aug 29 18:40:26 +0000 2015
# ...           ...                 ...                             ...
# 19995       19995  819336825231773698  Thu Jan 12 00:14:56 +0000 2017
# 19996       19996  819334654260080640  Thu Jan 12 00:06:18 +0000 2017
# 19997       19997  819334503042871297  Thu Jan 12 00:05:42 +0000 2017
# 19998       19998  819334419374899200  Thu Jan 12 00:05:22 +0000 2017
# 19999       19999  819334270825197568  Thu Jan 12 00:04:47 +0000 2017
#
#                                                post_text     user_id  \
# 0      its just over years since i was diagnosed with...  1013187241
# 1      its sunday i need a break so im planning to sp...  1013187241
# 2      awake but tired i need to sleep but my brain h...  1013187241
# 3      rt retro bears make perfect gifts and are grea...  1013187241
# 4      its hard to say whether packing lists are maki...  1013187241
# ...                                                  ...         ...
# 19995               a day without sunshine is like night  1169875706
# 19996  borens laws when in charge ponder when in trou...  1169875706
# 19997  the flow chart is a most thoroughly oversold p...  1169875706
# 19998  ships are safe in harbor but they were never m...  1169875706
# 19999      black holes are where god is dividing by zero  1169875706
#
#        followers  friends  favourites  statuses  retweets  label
# 0             84      211         251       837         0      1
# 1             84      211         251       837         1      1
# 2             84      211         251       837         0      1
# 3             84      211         251       837         2      1
# 4             84      211         251       837         1      1
# ...          ...      ...         ...       ...       ...    ...
# 19995        442      230           7   1063601         0      0
# 19996        442      230           7   1063601         0      0
# 19997        442      230           7   1063601         0      0
# 19998        442      230           7   1063601         0      0
# 19999        442      230           7   1063601         0      0
#
# [20000 rows x 11 columns]

# %% [markdown]
# After filtering the dataset to exclusively encompass tweets containing at least one word from the master keyword list, it is evident that the data has undergone a concentration process, resulting in a robust dataset comprising 7366 rows.

# %%
display(filtered_tweets_all)
# Out:
#        Unnamed: 0             post_id                    post_created  \
# 0               0  637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1               1  637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 3               3  637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4               4  637696327485366272  Sat Aug 29 18:40:26 +0000 2015
# 12             12  637555158440902656  Sat Aug 29 09:19:29 +0000 2015
# ...           ...                 ...                             ...
# 19984       19984  819341164147048449  Thu Jan 12 00:32:10 +0000 2017
# 19987       19987  819340814270615553  Thu Jan 12 00:30:47 +0000 2017
# 19993       19993  819337577601912835  Thu Jan 12 00:17:55 +0000 2017
# 19994       19994  819336993331171329  Thu Jan 12 00:15:36 +0000 2017
# 19995       19995  819336825231773698  Thu Jan 12 00:14:56 +0000 2017
#
#                                                post_text     user_id  \
# 0      its just over years since i was diagnosed with...  1013187241
# 1      its sunday i need a break so im planning to sp...  1013187241
# 3      rt retro bears make perfect gifts and are grea...  1013187241
# 4      its hard to say whether packing lists are maki...  1013187241
# 12     moving stuff is bloomin knackering and theres ...  1013187241
# ...                                                  ...         ...
# 19984  welcome to the working week i know it dont thr...  1169875706
# 19987  the internet is that thing still around homer ...  1169875706
# 19993  every why hath a wherefore william shakespeare...  1169875706
# 19994  you will have good luck and overcome many hard...  1169875706
# 19995               a day without sunshine is like night  1169875706
#
#        followers  friends  favourites  statuses  retweets  label
# 0             84      211         251       837         0      1
# 1             84      211         251       837         1      1
# 3             84      211         251       837         2      1
# 4             84      211         251       837         1      1
# 12            84      211         251       837         0      1
# ...          ...      ...         ...       ...       ...    ...
# 19984        442      230           7   1063601         0      0
# 19987        442      230           7   1063601         0      0
# 19993        442      230           7   1063601         0      0
# 19994        442      230           7   1063601         0      0
# 19995        442      230           7   1063601         0      0
#
# [7366 rows x 11 columns]

# %%
import pandas as pd

# saving filtered dataset to pandas
#filtered_tweets_all.to_csv('/content/drive/My Drive/Text Mining Project/mental_health_subset.csv', index=False)

# %% [markdown]
# Renaming final mental health dataset with top mental health related keywords

# %%
final_mh = filtered_tweets_all.drop(columns=['Unnamed: 0'])

# %%
display(final_mh)
# Out:
#                   post_id                    post_created  \
# 0      637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1      637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 3      637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4      637696327485366272  Sat Aug 29 18:40:26 +0000 2015
# 12     637555158440902656  Sat Aug 29 09:19:29 +0000 2015
# ...                   ...                             ...
# 19984  819341164147048449  Thu Jan 12 00:32:10 +0000 2017
# 19987  819340814270615553  Thu Jan 12 00:30:47 +0000 2017
# 19993  819337577601912835  Thu Jan 12 00:17:55 +0000 2017
# 19994  819336993331171329  Thu Jan 12 00:15:36 +0000 2017
# 19995  819336825231773698  Thu Jan 12 00:14:56 +0000 2017
#
#                                                post_text     user_id  \
# 0      its just over years since i was diagnosed with...  1013187241
# 1      its sunday i need a break so im planning to sp...  1013187241
# 3      rt retro bears make perfect gifts and are grea...  1013187241
# 4      its hard to say whether packing lists are maki...  1013187241
# 12     moving stuff is bloomin knackering and theres ...  1013187241
# ...                                                  ...         ...
# 19984  welcome to the working week i know it dont thr...  1169875706
# 19987  the internet is that thing still around homer ...  1169875706
# 19993  every why hath a wherefore william shakespeare...  1169875706
# 19994  you will have good luck and overcome many hard...  1169875706
# 19995               a day without sunshine is like night  1169875706
#
#        followers  friends  favourites  statuses  retweets  label
# 0             84      211         251       837         0      1
# 1             84      211         251       837         1      1
# 3             84      211         251       837         2      1
# 4             84      211         251       837         1      1
# 12            84      211         251       837         0      1
# ...          ...      ...         ...       ...       ...    ...
# 19984        442      230           7   1063601         0      0
# 19987        442      230           7   1063601         0      0
# 19993        442      230           7   1063601         0      0
# 19994        442      230           7   1063601         0      0
# 19995        442      230           7   1063601         0      0
#
# [7366 rows x 10 columns]

# %% [markdown]
# #Models Creation and testing

# %%
final_mh
# Out:
#                   post_id                    post_created  \
# 0      637894677824413696  Sun Aug 30 07:48:37 +0000 2015
# 1      637890384576778240  Sun Aug 30 07:31:33 +0000 2015
# 3      637696421077123073  Sat Aug 29 18:40:49 +0000 2015
# 4      637696327485366272  Sat Aug 29 18:40:26 +0000 2015
# 12     637555158440902656  Sat Aug 29 09:19:29 +0000 2015
# ...                   ...                             ...
# 19984  819341164147048449  Thu Jan 12 00:32:10 +0000 2017
# 19987  819340814270615553  Thu Jan 12 00:30:47 +0000 2017
# 19993  819337577601912835  Thu Jan 12 00:17:55 +0000 2017
# 19994  819336993331171329  Thu Jan 12 00:15:36 +0000 2017
# 19995  819336825231773698  Thu Jan 12 00:14:56 +0000 2017
#
#                                                post_text     user_id  \
# 0      its just over years since i was diagnosed with...  1013187241
# 1      its sunday i need a break so im planning to sp...  1013187241
# 3      rt retro bears make perfect gifts and are grea...  1013187241
# 4      its hard to say whether packing lists are maki...  1013187241
# 12     moving stuff is bloomin knackering and theres ...  1013187241
# ...                                                  ...         ...
# 19984  welcome to the working week i know it dont thr...  1169875706
# 19987  the internet is that thing still around homer ...  1169875706
# 19993  every why hath a wherefore william shakespeare...  1169875706
# 19994  you will have good luck and overcome many hard...  1169875706
# 19995               a day without sunshine is like night  1169875706
#
#        followers  friends  favourites  statuses  retweets  label
# 0             84      211         251       837         0      1
# 1             84      211         251       837         1      1
# 3             84      211         251       837         2      1
# 4             84      211         251       837         1      1
# 12            84      211         251       837         0      1
# ...          ...      ...         ...       ...       ...    ...
# 19984        442      230           7   1063601         0      0
# 19987        442      230           7   1063601         0      0
# 19993        442      230           7   1063601         0      0
# 19994        442      230           7   1063601         0      0
# 19995        442      230           7   1063601         0      0
#
# [7366 rows x 10 columns]

# %% [markdown]
# #Sentiment Analysis - BERT

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 259, done.
# remote: Total 259 (delta 0), reused 0 (delta 0), pack-reused 259
# Receiving objects: 100% (259/259), 516.15 KiB | 3.35 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Processing /content/bert-sklearn
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (2.1.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (1.5.3)
# Collecting boto3 (from bert-sklearn==0.3.1)
#   Downloading boto3-1.33.13-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 966.8 kB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bert-sklearn==0.3.1) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->bert-sklearn==0.3.1) (2.1.0)
# Collecting botocore<1.34.0,>=1.33.13 (from boto3->bert-sklearn==0.3.1)
#   Downloading botocore-1.33.13-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 45.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->bert-sklearn==0.3.1)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3->bert-sklearn==0.3.1)
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bert-sklearn==0.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bert-sklearn==0.3.1) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-sklearn==0.3.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-sklearn==0.3.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-sklearn==0.3.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-sklearn==0.3.1) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-sklearn==0.3.1) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-sklearn==0.3.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-sklearn==0.3.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->bert-sklearn==0.3.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.1->bert-sklearn==0.3.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->bert-sklearn==0.3.1) (1.3.0)
# Building wheels for collected packages: bert-sklearn
#   Building wheel for bert-sklearn (setup.py) ... done
#   Created wheel for bert-sklearn: filename=bert_sklearn-0.3.1-py3-none-any.whl size=54224 sha256=689597f625c96054e9a5218699f4b9738b26ff044796fb0c3d37d09a8dc25d3a
#   Stored in directory: /root/.cache/pip/wheels/29/f7/03/c9d257b287e1a5ef7ee4300cbbcd70cfbb13e8b6759da24477
# Successfully built bert-sklearn
# Installing collected packages: jmespath, botocore, s3transfer, boto3, bert-sklearn
# Successfully installed bert-sklearn-0.3.1 boto3-1.33.13 botocore-1.33.13 jmespath-1.0.1 s3transfer-0.8.2

# %%
# options
from bert_sklearn import BertClassifier
model = BertClassifier(bert_model='bert-base-uncased',
label_list=None,
num_mlp_hiddens=500,
num_mlp_layers=0,
epochs=1,
max_seq_length=128,
train_batch_size=32,
eval_batch_size=8,
learning_rate=2e-5,
warmup_proportion=0.1,
gradient_accumulation_steps=1,
fp16=False,
loss_scale=0,
local_rank=-1,
use_cuda=True,
random_state=42,
validation_fraction=0.1,
logfile='bert_sklearn.log' )
# Out:
# Building sklearn text classifier...

# %%
X_train_bert, y_train_bert = train160['text'].values, train160['label'].values
from bert_sklearn import BertClassifier
model_bert = BertClassifier(epochs=1)
print(model_bert)
model_bert.fit(X_train_bert, y_train_bert)
# Out:
# Building sklearn text classifier...
# BertClassifier(epochs=1)
# 100%|██████████| 231508/231508 [00:00<00:00, 2881914.35B/s]
# Loading bert-base-uncased model...
# 100%|██████████| 440473133/440473133 [00:16<00:00, 27401237.27B/s]
# 100%|██████████| 433/433 [00:00<00:00, 1182378.67B/s]
# Defaulting to linear classifier/regressor
# Loading Pytorch checkpoint
#
# train data size: 18000, validation data size: 2000
# Training  :   0%|          | 0/563 [00:00<?, ?it/s]
# Validating:   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch 1, Train loss: 0.5227, Val loss: 0.4568, Val accy: 76.45%
# BertClassifier(do_lower_case=True, epochs=1, label_list=array([0, 1]))

# %%
model_bert.save('bert-sentiment.model')

# %% [markdown]
# Classification report - BERT trained on sentiment data, tested on mental health data

# %%
from sklearn.metrics import classification_report

# Make predictions on the health data
y_pred_bert = model_bert.predict(final_mh['post_text'].values)

# Get the true labels from the Eureka dataset
y_true =final_mh['label'].values

# Generate the classification report
classification_rep = classification_report(y_true, y_pred_bert, target_names=['Negative','Positive'])

# Print the classification report
print("Classification Report:\n", classification_rep)
# Out:
# Predicting:   0%|          | 0/921 [00:00<?, ?it/s]
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative       0.83      0.61      0.70      3197
#     Positive       0.75      0.91      0.82      4169
#
#     accuracy                           0.78      7366
#    macro avg       0.79      0.76      0.76      7366
# weighted avg       0.79      0.78      0.77      7366

# %% [markdown]
# Error Analysis - BERT

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd


conf_matrix_bert = confusion_matrix(y_true, y_pred_bert)
print("Confusion Matrix:\n", conf_matrix_bert)


misclassified_indices_bert = y_true != y_pred_bert
misclassified_data_bert = final_mh.loc[misclassified_indices_bert, ['post_text', 'label']]


print("Misclassified Instances:")
display(misclassified_data_bert)
# Out:
# Confusion Matrix:
#  [[1944 1253]
#  [ 395 3774]]
# Misclassified Instances:
#                                                post_text  label
# 25     i will always love you peter gabriel in your eyes      1
# 115                        do you still use this account      1
# 155    gorilla has amazing reaction when reunited wit...      1
# 157    i scored points at kolor a game where you have...      1
# 176          its not your chair its all mine worldcatday      1
# ...                                                  ...    ...
# 19978  exactitude in small matters is the essence of ...      0
# 19981     change your thoughts and you change your world      0
# 19984  welcome to the working week i know it dont thr...      0
# 19994  you will have good luck and overcome many hard...      0
# 19995               a day without sunshine is like night      0
#
# [1648 rows x 2 columns]

# %% [markdown]
# #Sentiment Analysis - DistilBERT

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tqdm.notebook import tqdm

# %% [markdown]
# splitting data for training & testing

# %%
#mh = pd.read_csv('mental_health_subset.csv')
x_train, y_train = train160['text'].values, train160['label'].values
x_test, y_test = final_mh['post_text'].values, final_mh['label'].values

# %%
# Split the training data into train and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
# Load DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import Dataset

# Define the SentimentDataset class

class SentimentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = int(self.labels[idx])

        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score
import torch
# Tokenize the data
from torch.utils.data import Dataset

class SentimentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = int(self.labels[idx])

        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
import torch.nn as nn
# Create DataLoader for training and testing
train_dataset = SentimentDataset(x_train, y_train, tokenizer)
test_dataset = SentimentDataset(x_test, y_test, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Define optimizer and loss function
optimizer = AdamW(model.parameters(), lr=5e-5)
criterion = nn.CrossEntropyLoss()

# %%
 #Train the model
num_epochs = 2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(num_epochs):
    model.train()
    for batch in tqdm(train_loader, desc="Training"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask)
        loss = criterion(outputs.logits, labels)
        loss.backward()
        optimizer.step()
# Out:
# Training:   0%|          | 0/2000 [00:00<?, ?it/s]
# Training:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
# Evaluate the model
model.eval()
all_predictions = []
all_true_labels = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        predictions = torch.argmax(outputs.logits, dim=1)

        all_predictions.extend(predictions.cpu().numpy())
        all_true_labels.extend(labels.cpu().numpy())
# Out:
# Evaluating:   0%|          | 0/921 [00:00<?, ?it/s]

# %% [markdown]
# Classification report - DistilBERT trained on sentiment data, tested on mental health data
#
#
# along with error analysis

# %%
print("\nClassification Report on Testing Data:")
print(classification_report(all_true_labels, all_predictions))
print("\nConfusion Matrix:")
print(confusion_matrix(all_true_labels, all_predictions))
# Out:
# Classification Report on Testing Data:
#               precision    recall  f1-score   support
#
#            0       0.94      0.69      0.79      3197
#            1       0.80      0.97      0.88      4169
#
#     accuracy                           0.85      7366
#    macro avg       0.87      0.83      0.84      7366
# weighted avg       0.86      0.85      0.84      7366
#
#
# Confusion Matrix:
# [[2192 1005]
#  [ 133 4036]]

# %% [markdown]
# # Sentiment Analysis - MNB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
import numpy as np

# Step 1: Train Naive Bayes model on the Senti140 dataset
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
X_train = tfidf_vectorizer.fit_transform(train160['text'])
y_train = train160['label']  # Assuming 'label' column represents sentiment labels

# Introduce noise to the training labels
y_train_noisy = np.random.choice([0, 1], size=len(y_train), p=[0.5, 0.5])

# Train Naive Bayes model with noisy labels
naive_bayes_model = MultinomialNB(alpha=1.0)
naive_bayes_model.fit(X_train, y_train_noisy)
# Out:
# MultinomialNB()

# %%
# Step 3: Test Naive Bayes model on the subset of the mental health dataset
X_test = tfidf_vectorizer.transform(final_mh['post_text'])
y_true = final_mh['label']  # Assuming 'label' column represents the true labels

# Predict using the model with noisy labels
y_pred = naive_bayes_model.predict(X_test)

# Step 4: Evaluate the Naive Bayes model
accuracy = accuracy_score(y_true, y_pred)
auc_score = roc_auc_score(y_true, y_pred)
classification_rep = classification_report(y_true, y_pred)

print(f"Accuracy: {accuracy}")
print(f"AUC Score: {auc_score}")
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.5016291067064893
# AUC Score: 0.49875910591101197
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.48      0.45      3197
#            1       0.56      0.52      0.54      4169
#
#     accuracy                           0.50      7366
#    macro avg       0.50      0.50      0.50      7366
# weighted avg       0.51      0.50      0.50      7366

# %% [markdown]
# Error Analysis - MNB

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


conf_matrix = confusion_matrix(y_true, y_pred)
print(conf_matrix)


misclassified_indices = y_true != y_pred
misclassified_data = final_mh.loc[misclassified_indices, ['post_text', 'label']]

# Display Misclassified Instances
print("Misclassified Instances:")
display(misclassified_data)
# Out:
# [[1525 1672]
#  [1999 2170]]
# Misclassified Instances:
#                                                post_text  label
# 1      its sunday i need a break so im planning to sp...      1
# 3      rt retro bears make perfect gifts and are grea...      1
# 4      its hard to say whether packing lists are maki...      1
# 20     its do i get up or lie here a little longer wi...      1
# 21     theres nothing like cocktails and exhaustion t...      1
# ...                                                  ...    ...
# 19970  jacquins postulate on democratic government no...      0
# 19973  fs fitzgerald to hemingway ernest the rich are...      0
# 19974  in a five year period we can get one superb pr...      0
# 19978  exactitude in small matters is the essence of ...      0
# 19995               a day without sunshine is like night      0
#
# [3671 rows x 2 columns]

# %% [markdown]
# #Best Model - DistilBERT

# %% [markdown]
# Since distilbert has highest accuracy, we Filter instances where DistilBERT has correctly predicted label 0 for negative tweets

# %%
import pandas as pd

final_mh['Predicted Label'] = all_predictions


filtered_final_mh = final_mh[(final_mh['Predicted Label'] == 0) & (final_mh['label'] == 0)]


print(filtered_final_mh.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2192 entries, 10000 to 19993
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   post_id          2192 non-null   int64
#  1   post_created     2192 non-null   object
#  2   post_text        2192 non-null   object
#  3   user_id          2192 non-null   int64
#  4   followers        2192 non-null   int64
#  5   friends          2192 non-null   int64
#  6   favourites       2192 non-null   int64
#  7   statuses         2192 non-null   int64
#  8   retweets         2192 non-null   int64
#  9   label            2192 non-null   int64
#  10  Predicted Label  2192 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 205.5+ KB
# None
#                   post_id                    post_created  \
# 10000  819457334271279105  Thu Jan 12 08:13:47 +0000 2017
# 10017  819439102244356096  Thu Jan 12 07:01:21 +0000 2017
# 10023  819316582862221312  Wed Jan 11 22:54:30 +0000 2017
# 10026  819204798750793732  Wed Jan 11 15:30:18 +0000 2017
# 10029  819204113619709952  Wed Jan 11 15:27:35 +0000 2017
#
#                                                post_text             user_id  \
# 10000       my enemys invisible i dont know how to fight  727820220291645442
# 10017  i dont knwo the editing term for it but the sp...          3249600438
# 10023  he will only let himself be saved if she also ...          3249600438
# 10026  shows where i dont have to watch arrow even af...          3249600438
# 10029  and how can you possibly be true to dc univers...          3249600438
#
#        followers  friends  favourites  statuses  retweets  label  \
# 10000        123      145        1068     23801         0      0
# 10017        235      185       24407     22302         0      0
# 10023        235      185       24407     22302         0      0
# 10026        235      185       24407     22302         0      0
# 10029        235      185       24407     22302         0      0
#
#        Predicted Label
# 10000                0
# 10017                0
# 10023                0
# 10026                0
# 10029                0

# %%
display(filtered_final_mh)
# Out:
#                   post_id                    post_created  \
# 10000  819457334271279105  Thu Jan 12 08:13:47 +0000 2017
# 10017  819439102244356096  Thu Jan 12 07:01:21 +0000 2017
# 10023  819316582862221312  Wed Jan 11 22:54:30 +0000 2017
# 10026  819204798750793732  Wed Jan 11 15:30:18 +0000 2017
# 10029  819204113619709952  Wed Jan 11 15:27:35 +0000 2017
# ...                   ...                             ...
# 19973  819344882804424707  Thu Jan 12 00:46:57 +0000 2017
# 19976  819342226400702465  Thu Jan 12 00:36:24 +0000 2017
# 19983  819341171411550208  Thu Jan 12 00:32:12 +0000 2017
# 19987  819340814270615553  Thu Jan 12 00:30:47 +0000 2017
# 19993  819337577601912835  Thu Jan 12 00:17:55 +0000 2017
#
#                                                post_text             user_id  \
# 10000       my enemys invisible i dont know how to fight  727820220291645442
# 10017  i dont knwo the editing term for it but the sp...          3249600438
# 10023  he will only let himself be saved if she also ...          3249600438
# 10026  shows where i dont have to watch arrow even af...          3249600438
# 10029  and how can you possibly be true to dc univers...          3249600438
# ...                                                  ...                 ...
# 19973  fs fitzgerald to hemingway ernest the rich are...          1169875706
# 19976  i think trash is the most important manifestat...          1169875706
# 19983  while most peoples opinions change the convict...          1169875706
# 19987  the internet is that thing still around homer ...          1169875706
# 19993  every why hath a wherefore william shakespeare...          1169875706
#
#        followers  friends  favourites  statuses  retweets  label  \
# 10000        123      145        1068     23801         0      0
# 10017        235      185       24407     22302         0      0
# 10023        235      185       24407     22302         0      0
# 10026        235      185       24407     22302         0      0
# 10029        235      185       24407     22302         0      0
# ...          ...      ...         ...       ...       ...    ...
# 19973        442      230           7   1063601         0      0
# 19976        442      230           7   1063601         0      0
# 19983        442      230           7   1063601         0      0
# 19987        442      230           7   1063601         0      0
# 19993        442      230           7   1063601         0      0
#
#        Predicted Label
# 10000                0
# 10017                0
# 10023                0
# 10026                0
# 10029                0
# ...                ...
# 19973                0
# 19976                0
# 19983                0
# 19987                0
# 19993                0
#
# [2192 rows x 11 columns]

# %% [markdown]
# Count the number of negative tweets for each user

# %%
neg_tweet_count_by_user = filtered_final_mh.groupby('user_id').size().reset_index(name='neg_tweet_count')

neg_tweet_count_by_user = neg_tweet_count_by_user.sort_values(by='neg_tweet_count', ascending=False)

print(neg_tweet_count_by_user)
# Out:
#                user_id  neg_tweet_count
# 5            490044008              507
# 2            145626605              430
# 13          3249600438              338
# 17  763182466098233344              161
# 0             18831261              154
# 10          1497350173              126
# 12          2780518314              117
# 9           1458225506              104
# 8           1169875706               94
# 16  762433972273950725               58
# 4            324294391               37
# 3            171999132               23
# 1             29053403               16
# 7            894149342               13
# 11          2369443141                8
# 6            548972753                4
# 14  706699293558710273                1
# 15  727820220291645442                1

# %% [markdown]
# Now we are able to identify users by anonymity through their user_id and send variety of resources to them
